# %%
# Runner: bronze_gkg_pld_runner.ipynb
import sys
sys.path.append('./scripts')

from transform_bronze_gkg_pld import filter_gkg_for_pld

# Executar a transformação na Bronze
filter_gkg_for_pld()
# Out:
# ✅ Salvo: 20230901000000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901000000.gkg.csv
# ✅ Salvo: 20230901001500.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901001500.gkg.csv
# ✅ Salvo: 20230901003000.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901003000.gkg.csv
# ✅ Salvo: 20230901004500.gkg.csv — 1 linhas
# 🗑️ Deletado: 20230901004500.gkg.csv
# ✅ Salvo: 20230901010000.gkg.csv — 1 linhas
# 🗑️ Deletado: 20230901010000.gkg.csv
# ✅ Salvo: 20230901011500.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901011500.gkg.csv
# ✅ Salvo: 20230901013000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901013000.gkg.csv
# ✅ Salvo: 20230901014500.gkg.csv — 7 linhas
# 🗑️ Deletado: 20230901014500.gkg.csv
# ✅ Salvo: 20230901020000.gkg.csv — 6 linhas
# 🗑️ Deletado: 20230901020000.gkg.csv
# ✅ Salvo: 20230901021500.gkg.csv — 6 linhas
# 🗑️ Deletado: 20230901021500.gkg.csv
# ✅ Salvo: 20230901023000.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901023000.gkg.csv
# ✅ Salvo: 20230901024500.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901024500.gkg.csv
# ✅ Salvo: 20230901030000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901030000.gkg.csv
# ✅ Salvo: 20230901031500.gkg.csv — 9 linhas
# 🗑️ Deletado: 20230901031500.gkg.csv
# ✅ Salvo: 20230901033000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901033000.gkg.csv
# ✅ Salvo: 20230901034500.gkg.csv — 1 linhas
# 🗑️ Deletado: 20230901034500.gkg.csv
# ✅ Salvo: 20230901040000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901040000.gkg.csv
# ✅ Salvo: 20230901041500.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901041500.gkg.csv
# ✅ Salvo: 20230901043000.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901043000.gkg.csv
# ✅ Salvo: 20230901044500.gkg.csv — 6 linhas
# 🗑️ Deletado: 20230901044500.gkg.csv
# ✅ Salvo: 20230901050000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901050000.gkg.csv
# ✅ Salvo: 20230901051500.gkg.csv — 1 linhas
# 🗑️ Deletado: 20230901051500.gkg.csv
# ✅ Salvo: 20230901053000.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901053000.gkg.csv
# ✅ Salvo: 20230901054500.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901054500.gkg.csv
# ✅ Salvo: 20230901060000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901060000.gkg.csv
# ✅ Salvo: 20230901061500.gkg.csv — 9 linhas
# 🗑️ Deletado: 20230901061500.gkg.csv
# ✅ Salvo: 20230901063000.gkg.csv — 13 linhas
# 🗑️ Deletado: 20230901063000.gkg.csv
# ✅ Salvo: 20230901064500.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901064500.gkg.csv
# ✅ Salvo: 20230901070000.gkg.csv — 1 linhas
# 🗑️ Deletado: 20230901070000.gkg.csv
# ✅ Salvo: 20230901071500.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901071500.gkg.csv
# ✅ Salvo: 20230901073000.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901073000.gkg.csv
# ✅ Salvo: 20230901074500.gkg.csv — 1 linhas
# 🗑️ Deletado: 20230901074500.gkg.csv
# ✅ Salvo: 20230901080000.gkg.csv — 7 linhas
# 🗑️ Deletado: 20230901080000.gkg.csv
# ✅ Salvo: 20230901081500.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901081500.gkg.csv
# ✅ Salvo: 20230901083000.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901083000.gkg.csv
# ✅ Salvo: 20230901084500.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901084500.gkg.csv
# ✅ Salvo: 20230901090000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901090000.gkg.csv
# ✅ Salvo: 20230901091500.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901091500.gkg.csv
# ✅ Salvo: 20230901093000.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901093000.gkg.csv
# ✅ Salvo: 20230901094500.gkg.csv — 6 linhas
# 🗑️ Deletado: 20230901094500.gkg.csv
# ✅ Salvo: 20230901100000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901100000.gkg.csv
# ✅ Salvo: 20230901101500.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901101500.gkg.csv
# ✅ Salvo: 20230901103000.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901103000.gkg.csv
# ✅ Salvo: 20230901104500.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901104500.gkg.csv
# ✅ Salvo: 20230901110000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901110000.gkg.csv
# ❌ Erro ao processar 20230901111500.gkg.csv: 'utf-8' codec can't decode byte 0xa0 in position 523: invalid start byte
# ✅ Salvo: 20230901113000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901113000.gkg.csv
# ✅ Salvo: 20230901114500.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901114500.gkg.csv
# ✅ Salvo: 20230901120000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901120000.gkg.csv
# ✅ Salvo: 20230901121500.gkg.csv — 7 linhas
# 🗑️ Deletado: 20230901121500.gkg.csv
# ✅ Salvo: 20230901123000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901123000.gkg.csv
# ✅ Salvo: 20230901124500.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901124500.gkg.csv
# ✅ Salvo: 20230901130000.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901130000.gkg.csv
# ✅ Salvo: 20230901131500.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901131500.gkg.csv
# ✅ Salvo: 20230901133000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901133000.gkg.csv
# ✅ Salvo: 20230901134500.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901134500.gkg.csv
# ✅ Salvo: 20230901140000.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901140000.gkg.csv
# ✅ Salvo: 20230901141500.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901141500.gkg.csv
# 🗑️ Deletado: 20230901143000.gkg.csv
# ✅ Salvo: 20230901144500.gkg.csv — 6 linhas
# 🗑️ Deletado: 20230901144500.gkg.csv
# ✅ Salvo: 20230901150000.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901150000.gkg.csv
# ✅ Salvo: 20230901151500.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901151500.gkg.csv
# ✅ Salvo: 20230901153000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901153000.gkg.csv
# ✅ Salvo: 20230901154500.gkg.csv — 2 linhas
# 🗑️ Deletado: 20230901154500.gkg.csv
# ✅ Salvo: 20230901160000.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901160000.gkg.csv
# 🗑️ Deletado: 20230901161500.gkg.csv
# ✅ Salvo: 20230901163000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901163000.gkg.csv
# ✅ Salvo: 20230901164500.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901164500.gkg.csv
# ✅ Salvo: 20230901170000.gkg.csv — 20 linhas
# 🗑️ Deletado: 20230901170000.gkg.csv
# ✅ Salvo: 20230901171500.gkg.csv — 20 linhas
# 🗑️ Deletado: 20230901171500.gkg.csv
# ✅ Salvo: 20230901173000.gkg.csv — 15 linhas
# 🗑️ Deletado: 20230901173000.gkg.csv
# ✅ Salvo: 20230901174500.gkg.csv — 9 linhas
# 🗑️ Deletado: 20230901174500.gkg.csv
# ✅ Salvo: 20230901180000.gkg.csv — 13 linhas
# 🗑️ Deletado: 20230901180000.gkg.csv
# ✅ Salvo: 20230901181500.gkg.csv — 8 linhas
# 🗑️ Deletado: 20230901181500.gkg.csv
# ✅ Salvo: 20230901183000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901183000.gkg.csv
# ✅ Salvo: 20230901184500.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901184500.gkg.csv
# ✅ Salvo: 20230901190000.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901190000.gkg.csv
# ✅ Salvo: 20230901191500.gkg.csv — 8 linhas
# 🗑️ Deletado: 20230901191500.gkg.csv
# ✅ Salvo: 20230901193000.gkg.csv — 8 linhas
# 🗑️ Deletado: 20230901193000.gkg.csv
# ✅ Salvo: 20230901194500.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901194500.gkg.csv
# ✅ Salvo: 20230901200000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901200000.gkg.csv
# ✅ Salvo: 20230901201500.gkg.csv — 9 linhas
# 🗑️ Deletado: 20230901201500.gkg.csv
# ✅ Salvo: 20230901203000.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901203000.gkg.csv
# ✅ Salvo: 20230901204500.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901204500.gkg.csv
# ✅ Salvo: 20230901210000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901210000.gkg.csv
# ✅ Salvo: 20230901211500.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901211500.gkg.csv
# ✅ Salvo: 20230901213000.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901213000.gkg.csv
# ✅ Salvo: 20230901214500.gkg.csv — 7 linhas
# 🗑️ Deletado: 20230901214500.gkg.csv
# ✅ Salvo: 20230901220000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901220000.gkg.csv
# ✅ Salvo: 20230901221500.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901221500.gkg.csv
# 🗑️ Deletado: 20230901223000.gkg.csv
# ✅ Salvo: 20230901224500.gkg.csv — 6 linhas
# 🗑️ Deletado: 20230901224500.gkg.csv
# ✅ Salvo: 20230901230000.gkg.csv — 3 linhas
# 🗑️ Deletado: 20230901230000.gkg.csv
# 🗑️ Deletado: 20230901231500.gkg.csv
# ✅ Salvo: 20230901233000.gkg.csv — 4 linhas
# 🗑️ Deletado: 20230901233000.gkg.csv
# ✅ Salvo: 20230901234500.gkg.csv — 5 linhas
# 🗑️ Deletado: 20230901234500.gkg.csv
